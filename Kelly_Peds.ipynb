# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data from the image
data = {
    'FDI_Initial': [6, 19, 21, 27, 26, 38, 36, 34, 8, 31, 16],
    'FDI_3_month': [9, 13, 8, 26, 29, 39, 42, 28, 4, 9, 31],
    'FDI_6_month': [16, 18, 15, 17, 27, 38, 36, 30, 12, 9, 27],
    'GAD7_Initial': [5, 20, 8, 9, 16, 10, 13, 16, 9, 3, 2],
    'GAD7_3_month': [2, 5, 4, 9, 8, 7, 11, 11, 0, 4, 12],
    'GAD7_6_month': [2, 13, 2, 5, 2, 5, 14, 3, 2, 1, 18],
    'PHQ9_Initial': [9, 19, 7, 10, 12, 18, 21, 8, 6, 2, 3],
    'PHQ9_3_month': [9, 6, 1, 7, 5, 15, 17, 12, 4, 1, 6],
    'PHQ9_6_month': [9, 19, 1, 4, 1, 15, 17, 4, 2, 0, 16],
    'CSI24_Initial': [39, 43, 17, 34, 66, 59, 81, 70, 24, 37, 27],
    'CSI24_3_month': [39, 38, 16, 28, 53, 69, 77, 64, 24, 12, 54],
    'CSI24_6_month': [33, 45, 8, 40, 55, 61, 77, 74, 10, 8, 38]
}

df = pd.DataFrame(data)

# Reshape the DataFrame to a long format for plotting
df_long = pd.DataFrame()
scores = ['FDI', 'GAD7', 'PHQ9', 'CSI24']
time_points = ['Initial', '3-month', '6-month']

for score in scores:
    temp_df = df[[f'{score}_Initial', f'{score}_3_month', f'{score}_6_month']].copy()
    temp_df.columns = time_points # Rename columns for melting
    melted_temp_df = temp_df.melt(var_name='Time Point', value_name='Score')
    melted_temp_df['Score Type'] = score
    df_long = pd.concat([df_long, melted_temp_df])

# Create the four-panel box plots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
axes = axes.flatten() # Flatten the 2x2 array of axes for easy iteration

for i, score_type in enumerate(scores):
    sns.boxplot(x='Time Point', y='Score', data=df_long[df_long['Score Type'] == score_type], ax=axes[i])
    axes[i].set_title(f'{score_type} Score Distribution',fontweight='bold')
    axes[i].set_xlabel('Time Point',fontweight='bold')
    axes[i].set_ylabel('Score',fontweight='bold')
    axes[i].grid(axis='y', linestyle='--', alpha=0.7) # Add grid for readability

plt.tight_layout()
plt.savefig('Kelly_Figure1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data from the image
data = {
    'FDI_Initial': [6, 19, 21, 27, 26, 38, 36, 34, 8, 31, 16],
    'FDI_3_month': [9, 13, 8, 26, 29, 39, 42, 28, 4, 9, 31],
    'FDI_6_month': [16, 18, 15, 17, 27, 38, 36, 30, 12, 9, 27],
    'GAD7_Initial': [5, 20, 8, 9, 16, 10, 13, 16, 9, 3, 2],
    'GAD7_3_month': [2, 5, 4, 9, 8, 7, 11, 11, 0, 4, 12],
    'GAD7_6_month': [2, 13, 2, 5, 2, 5, 14, 3, 2, 1, 18],
    'PHQ9_Initial': [9, 19, 7, 10, 12, 18, 21, 8, 6, 2, 3],
    'PHQ9_3_month': [9, 6, 1, 7, 5, 15, 17, 12, 4, 1, 6],
    'PHQ9_6_month': [9, 19, 1, 4, 1, 15, 17, 4, 2, 0, 16],
    'CSI24_Initial': [39, 43, 17, 34, 66, 59, 81, 70, 24, 37, 27],
    'CSI24_3_month': [39, 38, 16, 28, 53, 69, 77, 64, 24, 12, 54],
    'CSI24_6_month': [33, 45, 8, 40, 55, 61, 77, 74, 10, 8, 38]
}

df = pd.DataFrame(data)

# Reshape the DataFrame to a long format for plotting
df_long = pd.DataFrame()
scores = ['FDI', 'GAD7', 'PHQ9', 'CSI24']
time_points = ['Initial', '3-month', '6-month']

for score in scores:
    temp_df = df[[f'{score}_Initial', f'{score}_3_month', f'{score}_6_month']].copy()
    temp_df.columns = time_points # Rename columns for melting
    melted_temp_df = temp_df.melt(var_name='Time Point', value_name='Score')
    melted_temp_df['Score Type'] = score
    df_long = pd.concat([df_long, melted_temp_df])

# Define fontdict for bold text
fontdict = {'fontsize': 12, 'fontweight': 'bold'}

# Create the four-panel box plots with data points and color
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
axes = axes.flatten() # Flatten the 2x2 array of axes for easy iteration

colors = sns.color_palette("viridis", n_colors=3)  # Use a colorful palette

for i, score_type in enumerate(scores):
    # Plot box plot
    sns.boxplot(x='Time Point', y='Score', data=df_long[df_long['Score Type'] == score_type], ax=axes[i], palette=[colors[0]], showfliers=False)

    # Overlay individual data points
    sns.stripplot(x='Time Point', y='Score', data=df_long[df_long['Score Type'] == score_type], ax=axes[i], jitter=True, color='black', size=4)

    axes[i].set_title(f'{score_type} Score Distribution', fontdict=fontdict)
    axes[i].set_xlabel('Time Point', fontdict=fontdict)
    axes[i].set_ylabel('Score', fontdict=fontdict)
    axes[i].grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for readability

plt.tight_layout()
plt.savefig('Kelly_Figure1_V2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\gangl\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gangl\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gangl\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data from Table H, treating blank cells as NaN
data = {
    'Prescribed_Initial': [2, 1, 3, 4, 6, 2, 13, 5, np.nan, 4, 6],
    'Prescribed_6_month': [3, 0, 3, 4, 4, 4, np.nan, 4, 1, 3, 2],
    'OTC_Initial': [0, np.nan, np.nan, np.nan, 4, 2, 2, 2, np.nan, 1, np.nan],
    'OTC_6_month': [2, 0, np.nan, 1, 2, 0, np.nan, 2, 4, 0, 0],
    'Vitamins_Initial': [0, np.nan, np.nan, 0, 4, 1, 3, 4, np.nan, 3, np.nan],
    'Vitamins_6_month': [2, 0, 7, 1, 3, 0, np.nan, 3, 1, 0, 0]
}

df = pd.DataFrame(data)

# Reshape the DataFrame to a long format for plotting
df_long = pd.DataFrame()
categories = ['Prescribed', 'OTC', 'Vitamins']
time_points = ['Initial', '6-month']

for category in categories:
    temp_df = df[[f'{category}_Initial', f'{category}_6_month']].copy()
    temp_df.columns = time_points # Rename columns for melting
    melted_temp_df = temp_df.melt(var_name='Time Point', value_name='Count')
    melted_temp_df['Category'] = category
    df_long = pd.concat([df_long, melted_temp_df])

# Define fontdict for bold text
fontdict = {'fontsize': 12, 'fontweight': 'bold'}

# Create the three-panel box plots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6)) # 1 row, 3 columns
axes = axes.flatten() # Flatten the 1x3 array of axes for easy iteration

colors = sns.color_palette("Set2", n_colors=len(time_points)) # Choose a colorful palette

for i, category_type in enumerate(categories):
    # Plot box plot
    sns.boxplot(x='Time Point', y='Count', data=df_long[df_long['Category'] == category_type], ax=axes[i], palette=colors, showfliers=False)

    # Overlay individual data points
    sns.stripplot(x='Time Point', y='Count', data=df_long[df_long['Category'] == category_type], ax=axes[i], jitter=0.2, color='black', size=5, linewidth=0.5)

    axes[i].set_title(f'Number of {category_type} Medication', fontdict=fontdict)
    axes[i].set_xlabel('Time Point', fontdict=fontdict)
    axes[i].set_ylabel('Count', fontdict=fontdict)
    axes[i].grid(axis='y', linestyle='--', alpha=0.7) # Add grid for readability

plt.tight_layout()
plt.savefig('Kelly_Figure2_V2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\gangl\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gangl\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gangl\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data from Table H, treating blank cells as NaN
data = {
    'Prescribed_Initial': [2, 1, 3, 4, 6, 2, 13, 5, np.nan, 4, 6],
    'Prescribed_6_month': [3, 0, 3, 4, 4, 4, np.nan, 4, 1, 3, 2],
    'OTC_Initial': [0, np.nan, np.nan, np.nan, 4, 2, 2, 2, np.nan, 1, np.nan],
    'OTC_6_month': [2, 0, np.nan, 1, 2, 0, np.nan, 2, 4, 0, 0],
    'Vitamins_Initial': [0, np.nan, np.nan, 0, 4, 1, 3, 4, np.nan, 3, np.nan],
    'Vitamins_6_month': [2, 0, 7, 1, 3, 0, np.nan, 3, 1, 0, 0]
}

df = pd.DataFrame(data)

# Reshape the DataFrame to a long format for plotting
df_long = pd.DataFrame()
categories = ['Prescribed', 'OTC', 'Vitamins']
time_points = ['Initial', '6-month']

for category in categories:
    temp_df = df[[f'{category}_Initial', f'{category}_6_month']].copy()
    temp_df.columns = time_points # Rename columns for melting
    melted_temp_df = temp_df.melt(var_name='Time Point', value_name='Count')
    melted_temp_df['Category'] = category
    df_long = pd.concat([df_long, melted_temp_df])

# Define fontdict for bold text
fontdict = {'fontsize': 12, 'fontweight': 'bold'}

# Create the three-panel box plots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6)) # 1 row, 3 columns
axes = axes.flatten() # Flatten the 1x3 array of axes for easy iteration

colors = sns.color_palette("Set2", n_colors=len(time_points)) # Choose a colorful palette

for i, category_type in enumerate(categories):
    # Plot box plot
    sns.boxplot(x='Time Point', y='Count', data=df_long[df_long['Category'] == category_type], ax=axes[i], palette=colors, showfliers=False)

    axes[i].set_title(f'Number of {category_type} Medication', fontdict=fontdict)
    axes[i].set_xlabel('Time Point', fontdict=fontdict)
    axes[i].set_ylabel('Count', fontdict=fontdict)
    axes[i].grid(axis='y', linestyle='--', alpha=0.7) # Add grid for readability

plt.tight_layout()
plt.savefig('Kelly_Figure2.png', dpi=300, bbox_inches='tight')
plt.savefig('Kelly_Figure2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data from Table H, treating blank cells as NaN
data = {
    'Prescribed_Initial': [2, 1, 3, 4, 6, 4, 2, 13, 5, 3, np.nan, 4, 6],
    'Prescribed_6_month': [3, 0, 3, 4, 4, 6, 4, np.nan, 4, 6, 1, 3, 2],
    'OTC_Initial': [0, np.nan, np.nan, np.nan, 4, 5, 2, 2, 2, 3, np.nan, 1, np.nan],
    'OTC_6_month': [2, 0, np.nan, 1, 2, 1, 0, np.nan, 2, 2, 4, 0, 0],
    'Vitamins_Initial': [0, np.nan, np.nan, 0, 4, 2, 1, 3, 4, 5, np.nan, 3, np.nan],
    'Vitamins_6_month': [2, 0, 7, 1, 3, 4, 0, np.nan, 3, 7, 1, 0, 0]
}

df = pd.DataFrame(data)

# Reshape the DataFrame to a long format for plotting
df_long = pd.DataFrame()
categories = ['Prescribed', 'OTC', 'Vitamins']
time_points = ['Initial', '6-month']

for category in categories:
    temp_df = df[[f'{category}_Initial', f'{category}_6_month']].copy()
    temp_df.columns = time_points # Rename columns for melting
    melted_temp_df = temp_df.melt(var_name='Time Point', value_name='Count')
    melted_temp_df['Category'] = category
    df_long = pd.concat([df_long, melted_temp_df])

# Define fontdict for bold text
fontdict = {'fontsize': 12, 'fontweight': 'bold'}

# Create the three-panel box plots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6)) # 1 row, 3 columns
axes = axes.flatten() # Flatten the 1x3 array of axes for easy iteration

colors = sns.color_palette("Set2", n_colors=len(time_points)) # Choose a colorful palette

for i, category_type in enumerate(categories):
    # Plot box plot (without individual data points)
    sns.boxplot(x='Time Point', y='Count', data=df_long[df_long['Category'] == category_type], ax=axes[i], palette=colors, showfliers=False)

    axes[i].set_title(f'Number of {category_type} Medications', fontdict=fontdict)
    if i==2:
        axes[i].set_title(f'Number of {category_type}', fontdict=fontdict)
    axes[i].set_xlabel('Time Point', fontdict=fontdict)
    axes[i].set_ylabel('Count', fontdict=fontdict)
    axes[i].grid(axis='y', linestyle='--', alpha=0.7) # Add grid for readability

plt.tight_layout()
plt.savefig('Kelly_Figure2.png', dpi=300, bbox_inches='tight')
plt.show()
