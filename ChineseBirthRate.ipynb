# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data from the image
data = {
    "Year": list(range(1949, 2024)),
    "Birth Rate (per 1000)": [
        36, 37, 37.8, 37, 37, 37.97, 32.6, 31.9, 34.03, 29.22, 24.78, 20.86, 18.02, 37.01, 43.37, 39.14, 37.88, 35.05,
        33.96, 35.59, 34.11, 33.43, 30.65, 29.77, 27.93, 24.82, 23.01, 19.91, 18.93, 18.25, 18.21, 18.21, 20.91, 22.28,
        20.19, 19.9, 21.04, 22.43, 23.33, 22.37, 21.58, 21.06, 19.68, 18.24, 18.09, 17.7, 17.12, 16.98, 16.57, 15.64,
        14.64, 14.03, 13.38, 12.86, 12.41, 12.29, 12.4, 12.09, 12.1, 12.14, 11.95, 11.9, 13.27, 14.57, 13.03, 13.83,
        11.99, 12.95, 12.64, 10.86, 10.41, 8.52, 7.52, 6.77, 6.39
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting the bar chart
plt.figure(figsize=(16, 8))
plt.bar(df["Year"], df["Birth Rate (per 1000)"], color='blue')
plt.title("Birth Rate in China (1949-2023)", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Birth Rate (per 1000)", fontsize=14)
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from 1949 to 2023
years = [
    1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
    1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
    1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
    2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023
]
birth_rates = [
    36, 37, 37.8, 37, 37, 37.97, 32.6, 31.9, 34.03, 29.22, 24.78, 20.86, 18.02, 37.01, 43.37, 39.14, 37.88, 35.05, 33.96, 35.59,
    34.11, 33.43, 30.65, 29.77, 27.93, 24.82, 23.01, 19.91, 18.93, 18.25, 18.21, 18.21, 20.91, 22.28, 20.19, 19.9, 21.04, 22.43, 23.33,
    22.37, 21.58, 21.06, 19.68, 18.24, 18.09, 17.7, 17.12, 16.98, 16.57, 15.64, 14.64, 14.03, 13.38, 12.86, 12.41, 12.29, 12.4, 12.09,
    12.1, 12.14, 11.95, 11.9, 13.27, 14.57, 13.03, 13.83, 11.99, 12.95, 12.64, 10.86, 10.41, 8.52, 7.52, 6.77, 6.39
]

# Set colors: Solid red for 1980-1990, transparent for others
colors = ['red' if 1958 <= year <= 1961 else (0, 0, 0, 0.1) for year in years]

# Plotting
plt.figure(figsize=(14, 6))
plt.bar(years, birth_rates, color=colors)
plt.title('Birth Rate in China (1949-2023)')
plt.xlabel('Year')
plt.ylabel('Birth Rate (per 1000)')
plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
plt.savefig("Birth Rate between 1958 and 1961.png", dpi=300, bbox_inches="tight")  # High-quality image
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the image
years = [
    1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
    1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
    1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
    2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023
]

birth_rate = [
    36, 37, 37.8, 37, 37, 37.97, 32.6, 31.9, 34.03, 29.22, 24.78, 20.86, 18.02, 37.01, 43.37, 39.14, 37.88, 35.05, 33.96,
    35.59, 34.11, 33.43, 30.65, 29.77, 27.93, 24.82, 23.01, 19.91, 18.93, 18.25, 18.21, 18.21, 20.91, 22.28, 20.19, 19.9,
    21.04, 22.43, 23.33, 22.37, 21.58, 21.06, 19.68, 18.24, 18.09, 17.7, 17.12, 16.98, 16.57, 15.64, 14.64, 14.03, 13.38,
    12.86, 12.41, 12.29, 12.4, 12.09, 12.1, 12.14, 11.95, 11.9, 13.27, 14.57, 13.03, 13.83, 11.99, 12.95, 12.64, 10.86,
    10.41, 8.52, 7.52, 6.77, 6.39
]

population = [
    537371000, 546815000, 557480000, 568910000, 581390000, 595310000, 608655000, 621465000, 637405000, 653235000,
    666005000, 667070000, 660330000, 665770000, 682335000, 698355000, 715185000, 735400000, 754550000, 774510000,
    796025000, 818315000, 841105000, 862030000, 881940000, 900350000, 916395000, 930685000, 943455000, 956165000,
    969005000, 981235000, 993885000, 1008630000, 1023310000, 1036825000, 1051040000, 1066790000, 1084035000,
    1101630000, 1118650000, 1135185000, 1150780000, 1164970000, 1178440000, 1191835000, 1204855000, 1217550000,
    1230075000, 1241935000, 1252735000, 1262645000, 1271850000, 1280400000, 1288400000, 1296075000, 1303720000,
    1311020000, 1317885000, 1324655000, 1331260000, 1337705000, 1345035000, 1354190000, 1363240000, 1371860000,
    1379860000, 1387790000, 1396215000, 1402760000, 1407745000, 1411100000, 1412360000, 1411750000, 1409670000
]

# Create dual-axis plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Primary y-axis for birth rate
ax1.set_xlabel('Year')
ax1.set_ylabel('Birth Rate (per 1000)', color='tab:blue')
ax1.plot(years, birth_rate, color='tab:blue', marker='o', label='Birth Rate')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Secondary y-axis for total population
ax2 = ax1.twinx()
ax2.set_ylabel('Total Population', color='tab:green')
ax2.plot(years, population, color='tab:green', marker='x', label='Total Population')
ax2.tick_params(axis='y', labelcolor='tab:green')

# Title and grid
plt.title('Birth Rate and Total Population Over Time')
fig.tight_layout()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the image
years = [
    1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023
]
birth_rate = [
    36, 37, 37.8, 37, 37, 37.97, 32.6, 31.9, 34.03, 29.22, 24.78, 20.86, 18.02, 37.01, 43.37, 39.14, 37.88, 35.05, 33.96, 35.59, 34.11, 33.43, 30.65, 29.77, 27.93, 24.82, 23.01, 19.91, 18.93, 18.25, 18.21, 18.21, 20.91, 22.28, 20.19, 19.9, 21.04, 22.43, 23.33, 22.37, 21.58, 21.06, 19.68, 18.24, 18.09, 17.7, 17.12, 16.98, 16.57, 15.64, 14.64, 14.03, 13.38, 12.86, 12.41, 12.29, 12.4, 12.09, 12.1, 12.14, 11.95, 11.9, 13.27, 14.57, 13.03, 13.83, 11.99, 12.95, 12.64, 10.86, 10.41, 8.52, 7.52, 6.77, 6.39
]
population = [
    537371000, 546815000, 557480000, 568910000, 581390000, 595310000, 608655000, 621465000, 637405000, 653235000, 666005000, 667070000, 660330000, 665770000, 682335000, 698355000, 715185000, 735400000, 754550000, 774510000, 796025000, 818315000, 841105000, 862030000, 881940000, 900350000, 916395000, 930685000, 943455000, 956165000, 969005000, 981235000, 993885000, 1008630000, 1023310000, 1036825000, 1051040000, 1066790000, 1084035000, 1101630000, 1118650000, 1135185000, 1150780000, 1164970000, 1178440000, 1191835000, 1204855000, 1217550000, 1230075000, 1241935000, 1252735000, 1262645000, 1271850000, 1280400000, 1288400000, 1296075000, 1303720000, 1311020000, 1317885000, 1324655000, 1331260000, 1337705000, 1345035000, 1354190000, 1363240000, 1371860000, 1379860000, 1387790000, 1396215000, 1402760000, 1407745000, 1411100000, 1412360000, 1411750000, 1409670000
]

# Create dual-axis plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar chart for birth rate
ax1.bar(years, birth_rate, color='red', label='Birth Rate (per 1000)')
ax1.set_xlabel('Year')
ax1.set_ylabel('Birth Rate (per 1000)', color='red')
ax1.tick_params(axis='y', labelcolor='red')

# Line chart for population (without markers)
ax2 = ax1.twinx()
ax2.plot(years, population, color='darkgreen', linestyle='-', linewidth=2, label='Total Population')
ax2.set_ylabel('Total Population', color='darkgreen')
ax2.tick_params(axis='y', labelcolor='darkgreen')

plt.title('Birth Rate and Total Population of China Between 1949 and 2023')
plt.savefig("Birth Rate and Total Population of China Between 1949 and 2023.png", dpi=300, bbox_inches="tight")  # High-quality image
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from 1949 to 2023
years = [
    1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
    1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
    1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
    2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023
]
birth_rates = [
    36, 37, 37.8, 37, 37, 37.97, 32.6, 31.9, 34.03, 29.22, 24.78, 20.86, 18.02, 37.01, 43.37, 39.14, 37.88, 35.05, 33.96, 35.59,
    34.11, 33.43, 30.65, 29.77, 27.93, 24.82, 23.01, 19.91, 18.93, 18.25, 18.21, 18.21, 20.91, 22.28, 20.19, 19.9, 21.04, 22.43, 23.33,
    22.37, 21.58, 21.06, 19.68, 18.24, 18.09, 17.7, 17.12, 16.98, 16.57, 15.64, 14.64, 14.03, 13.38, 12.86, 12.41, 12.29, 12.4, 12.09,
    12.1, 12.14, 11.95, 11.9, 13.27, 14.57, 13.03, 13.83, 11.99, 12.95, 12.64, 10.86, 10.41, 8.52, 7.52, 6.77, 6.39
]

# Set colors: Solid red for 1980-1990, transparent for others
colors = ['red' if 1978 <= year <= 2013 else (0, 0, 0, 0.1) for year in years]

# Plotting
plt.figure(figsize=(14, 6))
plt.bar(years, birth_rates, color=colors)
plt.title('Birth Rate in China (1949-2023)')
plt.xlabel('Year')
plt.ylabel('Birth Rate (per 1000)')
plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
plt.savefig("Birth Rate between 1978 and 2013.png", dpi=300, bbox_inches="tight")  # High-quality image
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from 1949 to 2023
years = [
    1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
    1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
    1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
    2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023
]
birth_rates = [
    36, 37, 37.8, 37, 37, 37.97, 32.6, 31.9, 34.03, 29.22, 24.78, 20.86, 18.02, 37.01, 43.37, 39.14, 37.88, 35.05, 33.96, 35.59,
    34.11, 33.43, 30.65, 29.77, 27.93, 24.82, 23.01, 19.91, 18.93, 18.25, 18.21, 18.21, 20.91, 22.28, 20.19, 19.9, 21.04, 22.43, 23.33,
    22.37, 21.58, 21.06, 19.68, 18.24, 18.09, 17.7, 17.12, 16.98, 16.57, 15.64, 14.64, 14.03, 13.38, 12.86, 12.41, 12.29, 12.4, 12.09,
    12.1, 12.14, 11.95, 11.9, 13.27, 14.57, 13.03, 13.83, 11.99, 12.95, 12.64, 10.86, 10.41, 8.52, 7.52, 6.77, 6.39
]

# Set colors: Solid red for 1980-1990, transparent for others
colors = ['red' if 2014 <= year <= 2023 else (0, 0, 0, 0.1) for year in years]

# Plotting
plt.figure(figsize=(14, 6))
plt.bar(years, birth_rates, color=colors)
plt.title('Birth Rate in China (1949-2023)')
plt.xlabel('Year')
plt.ylabel('Birth Rate (per 1000)')
plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
plt.savefig("Birth Rate between 2014 and 2023.png", dpi=300, bbox_inches="tight")  # High-quality image
plt.show()
