# %%
import matplotlib.pyplot as plt

# Sample data for the number of births in the USA for the last 10 years
# These are placeholder values; real data should be sourced from reliable datasets.
years = list(range(2004, 2024))
births = [
    4080000, 4110000, 4130000, 4190000, 4240000, 4260000, 4010000, 3960000, 3920000, 3880000, 
    3860000, 3850000, 3820000, 3810000, 3780000, 3750000, 3740000, 3730000, 3700000, 3690000
]

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(years, births, marker='o', linestyle='-', color='b', label='Number of Births')

# Add titles and labels
plt.title("Number of Births in the USA (2004-2023)", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Births (in millions)", fontsize=12)
plt.xticks(years, rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()

# Show the plot
plt.savefig('USA_TwentyYears.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create the plot
fig, ax = plt.subplots()
ax.plot(x, y, label="Sine Wave")

# Add background text
ax.text(5, 0, 'BACKGROUND', fontsize=50, color='gray', alpha=0.3,
        ha='center', va='center', rotation=30)

# Labels and title
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_title("Plot with Background Text")
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Define xticks using a variable
xticks_values = np.arange(0, 11, 2)  # xticks from 0 to 10 with step 2

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(6, 6))  # 2 rows, 1 column

# Plot on first subplot
axs[0].plot(x, y1)
axs[0].set_title("Sine Wave")
axs[0].set_xticks(xticks_values)
axs[0].set_xticklabels(xticks_values, rotation=45)  # Rotate xticks 45 degrees

# Plot on second subplot
axs[1].plot(x, y2)
axs[1].set_title("Cosine Wave")
axs[1].set_xticks(xticks_values)
axs[1].set_xticklabels(xticks_values, rotation=30)  # Rotate xticks 30 degrees

# Adjust layout and show
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample birth data (Replace with actual data if available)
years = np.arange(2004, 2024)
births_usa = [
    4080000, 4110000, 4130000, 4190000, 4240000, 4260000, 4010000, 3960000, 3920000, 3880000, 
    3860000, 3850000, 3820000, 3810000, 3780000, 3750000, 3740000, 3730000, 3700000, 3690000
]
births_china = [
    15900000, 16000000, 16100000, 16500000, 16800000, 17500000, 18000000, 17200000, 17100000, 
    15900000, 14600000, 14000000, 13400000, 12000000, 11800000, 11200000, 10500000, 10000000, 
    9500000, 9200000
]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot USA and China birth data
ax.plot(years, births_usa, marker='o', linestyle='-', label="USA Births", color='blue')
ax.plot(years, births_china, marker='s', linestyle='--', label="China Births", color='red')

# Set title and labels
ax.set_title("Comparison of Births in USA and China (2004-2023)", fontsize=14)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Number of Births", fontsize=12)
ax.legend()

# Set xticks for better readability
ax.set_xticks(years[::2])  # Show every 2nd year
ax.tick_params(axis='x', rotation=45)  # Rotate x-axis labels for readability

# Add background text
ax.text(2013, max(births_china) * 0.7, 'Rednote ID:1046061966', fontsize=30, color='gray', alpha=0.3,
        ha='center', va='center', rotation=30)

# Show the plot
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('Comparison_China_USA_TwentyYears.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample birth data (Replace with actual data if available)
years = np.arange(2004, 2024)
births_usa = [
    4080000, 4110000, 4130000, 4190000, 4240000, 4260000, 4010000, 3960000, 3920000, 3880000, 
    3860000, 3850000, 3820000, 3810000, 3780000, 3750000, 3740000, 3730000, 3700000, 3690000
]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot USA and China birth data
ax.plot(years, births_usa, marker='o', linestyle='-', label="USA Births", color='blue')

# Set title and labels
ax.set_title("Number of Births in USA (2004-2023)", fontsize=14)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Number of Births", fontsize=12)
ax.legend()

# Set xticks for better readability
ax.set_xticks(years[::2])  # Show every 2nd year
ax.tick_params(axis='x', rotation=45)  # Rotate x-axis labels for readability

# Add background text
ax.text(2013, max(births_usa)*0.95, 'Rednote ID:1046061966', fontsize=30, color='gray', alpha=0.3,
        ha='center', va='center', rotation=30)

# Show the plot
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('USA_TwentyYears.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for top 10 cities with the highest average salary in China (2024)
cities = ['Shanghai', 'Beijing', 'Shenzhen', 'Hangzhou', 'Nanjing', 'Suzhou', 'Guangzhou', 'Ningbo', 'Zhuhai', 'Xiamen']
average_salaries = [13486, 13438, 12774, 11796, 11061, 10933, 10883, 10704, 10425, 10403]
cost_of_living = [10500, 10200, 9800, 8500, 8200, 8100, 8300, 7900, 7700, 7600]  # Hypothetical cost of living data

x = np.arange(len(cities))  # X-axis positions

fig, ax1 = plt.subplots(figsize=(12,6))

# First y-axis (Average Salary - Vertical Bar Chart)
ax1.bar(x, average_salaries, color='skyblue', label='Average Salary')
ax1.set_xlabel('Cities', fontsize=12)
ax1.set_ylabel('Average Salary (CNY)', fontsize=12, color='blue')
ax1.set_xticks(x)
ax1.set_xticklabels(cities, rotation=45, ha='right')
ax1.tick_params(axis='y', labelcolor='blue')

# Second y-axis (Cost of Living - Line Plot)
ax2 = ax1.twinx()
ax2.plot(x, cost_of_living, color='red', marker='o', linestyle='-', linewidth=2, markersize=6, label='Cost of Living')
ax2.set_ylabel('Cost of Living (CNY)', fontsize=12, color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add background text
plt.text(0.5, 0.5, 'Rednote ID:1046061966', fontsize=20, color='gray', alpha=0.3,
         ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Top 10 Cities: Salary vs. Cost of Living in China (2024)', fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for top 10 cities with the highest average salary in China (2024)
cities = ['Shanghai', 'Beijing', 'Shenzhen', 'Hangzhou', 'Nanjing', 'Suzhou', 'Guangzhou', 'Ningbo', 'Zhuhai', 'Xiamen']
average_salaries = [13486, 13438, 12774, 11796, 11061, 10933, 10883, 10704, 10425, 10403]
cost_of_living = [10500, 10200, 9800, 8500, 8200, 8100, 8300, 7900, 7700, 7600]  # Hypothetical cost of living data

fig, ax1 = plt.subplots(figsize=(10,6))

# First y-axis (Salary)
ax1.barh(cities, average_salaries, color='skyblue', label='Average Salary')
ax1.set_xlabel('Average Salary (CNY)', fontsize=12)
ax1.set_ylabel('Cities', fontsize=12)
ax1.set_title('Top 10 Cities: Salary vs. Cost of Living in China (2024)', fontsize=14)

# Second y-axis (Cost of Living)
ax2 = ax1.twiny()
ax2.plot(cost_of_living, cities, 'ro-', label='Cost of Living')
ax2.set_xlabel('Cost of Living (CNY)', fontsize=12, color='red')

# Add background text
plt.text(0.5, 0.5, 'Rednote ID:1046061966', fontsize=20, color='gray', alpha=0.3,
         ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the CSV file
file_path = "C:/Users/gangl/Documents/Python Scripts/Shaanxi.csv"
data = np.loadtxt(file_path, delimiter=",", skiprows=1)
print("First 5 rows of data:\n", data[:5])
# Data
years = data[:, 0]
GDP_per_capita = data[:, 1]
National_ranking = data[:, 2]

# plot data
fig, ax1 = plt.subplots(figsize=(12,7))

# First y-axis (Average Salary - Vertical Bar Chart)
ax1.bar(years, GDP_per_capita, color='skyblue', label='GDP Per Capita')
ax1.set_xlabel('Yeas', fontsize=12)
ax1.set_ylabel('GDP Per Capita (CNY)', fontsize=12, color='blue')
ax1.set_xticks(x)
ax1.set_xticklabels(years, rotation=45, ha='right')
ax1.tick_params(axis='y', labelcolor='blue')

# Second y-axis (Cost of Living - Line Plot)
ax2 = ax1.twinx()
ax2.plot(years, National_ranking, color='red', marker='o', linestyle='-', linewidth=2, markersize=6, label='National Ranking')
ax2.set_ylabel('National Ranking (The Lower, the better)', fontsize=12, color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add background text
plt.text(0.5, 0.5, 'Rednote ID:1046061966', fontsize=20, color='gray', alpha=0.3,
         ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('GDP per capita and national ranking of Shaanxi Province (2003 - 2022)', fontsize=13)
plt.show()
# Out:
# First 5 rows of data:
#  [[ 2003.  5773.    23.]
#  [ 2004.  6827.    22.]
#  [ 2005.  8071.    22.]
#  [ 2006.  9488.    21.]
#  [ 2007. 11182.    21.]]

# %%
import pandas as pd
import numpy as np

# Load the CSV file
file_path = "C:/Users/gangl/Documents/Python Scripts/Shaanxi.csv"
df = pd.read_csv(file_path)

print(df.head())
print(df.info())
print(df.describe())


data = np.loadtxt(file_path, delimiter=",", skiprows=1)  # Skip header row

# Display first 5 rows
print("First 5 rows of data:\n", data[:5])

x = data[:, 0]  # First column
y = data[:, 1]  # Second column

# Create a simple line plot
plt.figure(figsize=(8,5))
plt.plot(x, y, marker="o", linestyle="-", color="b", label="Data Plot")

# Customize plot
plt.xlabel("X-axis Label")  # Change label as per data
plt.ylabel("Y-axis Label")
plt.title("CSV Data Plot Using NumPy & Matplotlib")
plt.legend()
plt.grid()

# Show the plot
plt.show()
# Out:
#    Years  GDP_per_capita  National_ranking
# 0   2003            5773                23
# 1   2004            6827                22
# 2   2005            8071                22
# 3   2006            9488                21
# 4   2007           11182                21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Years             20 non-null     int64
#  1   GDP_per_capita    20 non-null     int64
#  2   National_ranking  20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes
# None
#             Years  GDP_per_capita  National_ranking
# count    20.00000       20.000000         20.000000
# mean   2012.50000    27189.800000         17.000000
# std       5.91608    16382.759891          3.741657
# min    2003.00000     5773.000000         12.000000
# 25%    2007.75000    12618.250000         13.750000
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the CSV file
file_path = "C:/Users/gangl/Documents/Python Scripts/Shaanxi.csv"
data = np.loadtxt(file_path, delimiter=",", skiprows=1)
# Data
years = data[:, 0].astype(int)
print(years)
GDP_per_capita = data[:, 1]
National_ranking = data[:, 2]

# plot data
fig, ax1 = plt.subplots(figsize=(12,7))

# First y-axis (Average Salary - Vertical Bar Chart)
ax1.bar(years, GDP_per_capita, color='blue', label='GDP Per Capita')
ax1.set_xlabel('Yeas', fontsize=12)
ax1.set_ylabel('GDP Per Capita (CNY)', fontsize=12, color='blue')
ax1.set_xticks(years)
ax1.set_xticklabels(years, rotation=45, ha='right')
ax1.tick_params(axis='y', labelcolor='blue')

# Second y-axis (Cost of Living - Line Plot)
ax2 = ax1.twinx()
ax2.plot(years, National_ranking, color='red', marker='o', linestyle='-', linewidth=2, markersize=6, label='National Ranking')
ax2.set_ylabel('National Ranking (the lower, the better)', fontsize=12, color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add background text
plt.text(0.5, 0.5, 'Rednote ID:1046061966', fontsize=20, color='gray', alpha=0.3,
         ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Legends
ax1.legend(loc='upper center')
ax2.legend(loc='upper right')

plt.title('GDP per capita and national ranking of Shaanxi province (2003 - 2022)', fontsize=13)
plt.savefig('Shaanxi.png')
plt.show()
# Out:
# [2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016
#  2017 2018 2019 2020 2021 2022]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams["font.family"] = "SimHei"  # 黑体字体，支持中文
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示问题

# Load the CSV file
file_path = "C:/Users/gangl/Documents/Python Scripts/Shaanxi.csv"
data = np.loadtxt(file_path, delimiter=",", skiprows=1)
# Data
years = data[:, 0].astype(int)
print(years)
GDP_per_capita = data[:, 1].astype(int)
National_ranking = data[:, 2].astype(int)

# plot data
fig, ax1 = plt.subplots(figsize=(10,12))

# First y-axis (GDP - Vertical Bar Chart)
ax1.bar(years, GDP_per_capita, color='blue', label='人均GDP')
ax1.set_xlabel('Years', fontsize=28)
ax1.set_ylabel('人均GDP (元)', fontsize=28, color='blue')
ax1.set_yticks(GDP_per_capita)
ax1.set_yticklabels(GDP_per_capita, fontsize=15)
ax1.set_xticks(years)
ax1.set_xticklabels(years, fontsize=15,rotation=45, ha='center')
ax1.tick_params(axis='y', labelcolor='blue')

# Second y-axis (Ranking - Line Plot)
ax2 = ax1.twinx()
ax2.plot(years, National_ranking, color='red', marker='o', linestyle='-', linewidth=2, markersize=8, label='全国排名')
ax2.set_ylabel('全国排名 (越低越好)', fontsize=28, color='red')
ax2.set_yticks(National_ranking)
ax2.set_yticklabels(National_ranking, fontsize=15)
ax2.tick_params(axis='y', labelcolor='red')

# Add background text
plt.text(0.5, 0.5, 'Rednote ID:1046061966', fontsize=20, color='gray', alpha=0.3,
         ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Legends
ax1.legend(loc='upper center', fontsize=15)
ax2.legend(loc='upper right', fontsize=15)

plt.title('陕西省2003到2022年人均GPD以及在全国的排名（不含港澳台）', fontsize=18)
plt.savefig('Shaanxi_Chinese.png')
plt.show()
# Out:
# [2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016
#  2017 2018 2019 2020 2021 2022]

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "SimHei"  # 黑体字体，支持中文
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示问题
# Data
cities = ["上海", "北京", "深圳", "广州", "苏州", "杭州", "南京", "宁波", "厦门", "绍兴"]
average_salaries = [84834, 81752, 76910, 74837, 74076, 73797, 72112, 71731, 71062, 69707]

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.barh(cities, average_salaries, color='blue')
plt.xlabel('人均可支配收入 (元)')
plt.title('2023年中国人均可支配收入最高的十个城市')

plt.text(0.5, 0.5, "数据大观", fontsize=40, color="gray",
         alpha=0.3, ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Adding data labels
for bar in bars:
    plt.text(bar.get_width() + 100, bar.get_y() + bar.get_height()/2,
             f'{bar.get_width():,}', va='center', ha='left')

plt.gca().invert_yaxis()  # Highest salary at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "SimHei"  # 黑体字体，支持中文
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示问题
# Data
cities = ["上海", "北京", "深圳", "广州", "苏州", "杭州", "南京", "宁波", "厦门", "绍兴"]
average_salaries = [84834, 81752, 76910, 74837, 74076, 73797, 72112, 71731, 71062, 69707]

# Create figure
plt.figure(figsize=(10, 12))
bars = plt.bar(cities, average_salaries, color='blue')

# Add labels
plt.ylabel('人均可支配收入 (元)',fontsize=16)
plt.xlabel("城市", fontsize=16)
plt.title('2023年中国人均可支配收入最高的十个城市',fontsize=16)

# Rotate x-axis labels for better readability
# plt.xticks(rotation=45)

# Add grid lines for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add background text
plt.text(0.5, 0.5, "数据大观", fontsize=40, color="gray",
         alpha=0.3, ha='center', va='center', transform=plt.gca().transAxes, rotation=30)

# Add labels on bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 200,
             f'{bar.get_height():,}', ha='center', fontsize=16)

# Show the plot
plt.savefig('Top10Cities.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 创建数据
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# 绘制等高线图
plt.contour(X, Y, Z, levels=10)  # 使用contour函数绘制等高线
plt.colorbar()  # 添加颜色条
plt.xlabel('x')
plt.ylabel('y')
plt.title('等高线图')

plt.show()
