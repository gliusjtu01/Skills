# %%
import random
import heapq
import numpy as np

# Simulation parameters
SIMULATION_TIME = 1000  # minutes
NUM_DOCTORS = 3
MEAN_INTERARRIVAL_TIME = 5  # minutes
SERVICE_TIMES = {1: 15, 2: 10, 3: 5}  # average service times by triage level
TRIAGE_PROBS = [0.2, 0.5, 0.3]  # high, medium, low priority

# Event queue: (time, event_type, patient)
event_queue = []

# Priority queue for waiting patients: (priority, arrival_time, patient_id)
waiting_patients = []

# Doctors: list of (available_time, doctor_id)
doctors = [(0, i) for i in range(NUM_DOCTORS)]

# Tracking
patient_id_counter = 0
all_wait_times = []
doctor_busy_times = [0] * NUM_DOCTORS


def generate_interarrival_time():
    return np.random.exponential(MEAN_INTERARRIVAL_TIME)


def assign_triage_level():
    return np.random.choice([1, 2, 3], p=TRIAGE_PROBS)


def generate_service_time(triage_level):
    return np.random.exponential(SERVICE_TIMES[triage_level])


def schedule_event(time, event_type, patient):
    heapq.heappush(event_queue, (time, event_type, patient))


def find_available_doctor(current_time):
    for i in range(len(doctors)):
        if doctors[i][0] <= current_time:
            return i
    return None


# Start simulation by scheduling the first arrival
current_time = 0
first_patient = {
    'id': patient_id_counter,
    'arrival_time': 0,
    'triage_level': assign_triage_level()
}
schedule_event(0, 'arrival', first_patient)

while current_time < SIMULATION_TIME and event_queue:
    current_time, event_type, patient = heapq.heappop(event_queue)

    if event_type == 'arrival':
        print(f"Time {current_time:.2f}: Patient {patient['id']} arrives with triage level {patient['triage_level']}")
        patient_id_counter += 1

        # Add patient to the waiting queue (min-heap by priority and arrival)
        heapq.heappush(waiting_patients, (patient['triage_level'], patient['arrival_time'], patient['id'], patient))

        # Schedule next arrival
        next_arrival_time = current_time + generate_interarrival_time()
        if next_arrival_time < SIMULATION_TIME:
            new_patient = {
                'id': patient_id_counter,
                'arrival_time': next_arrival_time,
                'triage_level': assign_triage_level()
            }
            schedule_event(next_arrival_time, 'arrival', new_patient)

        # Attempt to serve waiting patient
        doc_idx = find_available_doctor(current_time)
        if doc_idx is not None and waiting_patients:
            _, arrival_time, _, next_patient = heapq.heappop(waiting_patients)
            wait_time = current_time - arrival_time
            all_wait_times.append(wait_time)
            service_time = generate_service_time(next_patient['triage_level'])
            finish_time = current_time + service_time
            doctors[doc_idx] = (finish_time, doc_idx)
            doctor_busy_times[doc_idx] += service_time
            print(f"  Doctor {doc_idx} starts serving Patient {next_patient['id']} (waited {wait_time:.2f} mins)")
            schedule_event(finish_time, 'departure', next_patient)

    elif event_type == 'departure':
        print(f"Time {current_time:.2f}: Patient {patient['id']} departs")

        # Free up doctor and check for next patient
        doc_idx = find_available_doctor(current_time)
        if doc_idx is not None and waiting_patients:
            _, arrival_time, _, next_patient = heapq.heappop(waiting_patients)
            wait_time = current_time - arrival_time
            all_wait_times.append(wait_time)
            service_time = generate_service_time(next_patient['triage_level'])
            finish_time = current_time + service_time
            doctors[doc_idx] = (finish_time, doc_idx)
            doctor_busy_times[doc_idx] += service_time
            print(f"  Doctor {doc_idx} starts serving Patient {next_patient['id']} (waited {wait_time:.2f} mins)")
            schedule_event(finish_time, 'departure', next_patient)

# Performance metrics
print("\nSimulation Complete.\n")
print(f"Total patients served: {len(all_wait_times)}")
print(f"Average wait time: {np.mean(all_wait_times):.2f} minutes")
for i, busy_time in enumerate(doctor_busy_times):
    utilization = (busy_time / SIMULATION_TIME) * 100
    print(f"Doctor {i} utilization: {utilization:.2f}%")
# Out:
# Time 0.00: Patient 0 arrives with triage level 2
#   Doctor 0 starts serving Patient 0 (waited 0.00 mins)
# Time 3.82: Patient 1 arrives with triage level 3
#   Doctor 1 starts serving Patient 1 (waited 0.00 mins)
# Time 7.20: Patient 2 arrives with triage level 1
#   Doctor 2 starts serving Patient 2 (waited 0.00 mins)
# Time 10.25: Patient 0 departs
# Time 10.54: Patient 1 departs
# Time 11.20: Patient 3 arrives with triage level 2
#   Doctor 0 starts serving Patient 3 (waited 0.00 mins)
# Time 11.87: Patient 2 departs
# Time 12.46: Patient 4 arrives with triage level 1
#   Doctor 1 starts serving Patient 4 (waited 0.00 mins)
# Time 18.34: Patient 3 departs
# Time 23.44: Patient 5 arrives with triage level 2
#   Doctor 0 starts serving Patient 5 (waited 0.00 mins)
# Time 25.13: Patient 5 departs
# Time 27.50: Patient 6 arrives with triage level 2
#   Doctor 0 starts serving Patient 6 (waited 0.00 mins)
# Time 30.86: Patient 7 arrives with triage level 3
#   Doctor 2 starts serving Patient 7 (waited 0.00 mins)
# Time 33.19: Patient 6 departs
# Time 36.98: Patient 4 departs
# Time 37.82: Patient 8 arrives with triage level 2
#   Doctor 0 starts serving Patient 8 (waited 0.00 mins)
# Time 39.05: Patient 9 arrives with triage level 2
#   Doctor 1 starts serving Patient 9 (waited 0.00 mins)
# Time 40.77: Patient 9 departs
# Time 41.01: Patient 10 arrives with triage level 2
#   Doctor 1 starts serving Patient 10 (waited 0.00 mins)
# Time 41.10: Patient 10 departs
# Time 41.23: Patient 8 departs
# Time 42.53: Patient 7 departs
# Time 47.89: Patient 11 arrives with triage level 2
#   Doctor 0 starts serving Patient 11 (waited 0.00 mins)
# Time 48.84: Patient 11 departs
# Time 51.33: Patient 12 arrives with triage level 1
#   Doctor 0 starts serving Patient 12 (waited 0.00 mins)
# Time 52.72: Patient 13 arrives with triage level 3
#   Doctor 1 starts serving Patient 13 (waited 0.00 mins)
# Time 54.36: Patient 12 departs
# Time 56.14: Patient 13 departs
# Time 64.25: Patient 14 arrives with triage level 3
#   Doctor 0 starts serving Patient 14 (waited 0.00 mins)
# Time 69.58: Patient 15 arrives with triage level 3
#   Doctor 1 starts serving Patient 15 (waited 0.00 mins)
# Time 69.66: Patient 15 departs
# Time 72.54: Patient 16 arrives with triage level 2
#   Doctor 1 starts serving Patient 16 (waited 0.00 mins)
# Time 72.87: Patient 17 arrives with triage level 2
#   Doctor 2 starts serving Patient 17 (waited 0.00 mins)
# Time 72.91: Patient 18 arrives with triage level 1
# Time 73.51: Patient 19 arrives with triage level 3
# Time 73.91: Patient 14 departs
#   Doctor 0 starts serving Patient 18 (waited 1.00 mins)
# Time 73.97: Patient 20 arrives with triage level 2
# Time 74.34: Patient 17 departs
#   Doctor 2 starts serving Patient 20 (waited 0.37 mins)
# Time 79.60: Patient 18 departs
#   Doctor 0 starts serving Patient 19 (waited 6.08 mins)
# Time 80.49: Patient 21 arrives with triage level 3
# Time 83.71: Patient 22 arrives with triage level 1
# Time 84.98: Patient 23 arrives with triage level 1
# Time 89.98: Patient 16 departs
#   Doctor 1 starts serving Patient 22 (waited 6.28 mins)
# Time 90.62: Patient 24 arrives with triage level 2
# Time 94.74: Patient 19 departs
#   Doctor 0 starts serving Patient 23 (waited 9.76 mins)
# Time 96.10: Patient 20 departs
#   Doctor 2 starts serving Patient 24 (waited 5.48 mins)
# Time 102.00: Patient 25 arrives with triage level 2
# Time 102.36: Patient 26 arrives with triage level 1
# Time 103.02: Patient 23 departs
#   Doctor 0 starts serving Patient 26 (waited 0.66 mins)
# Time 113.01: Patient 27 arrives with triage level 2
# Time 115.66: Patient 28 arrives with triage level 3
# Time 115.95: Patient 24 departs
#   Doctor 2 starts serving Patient 25 (waited 13.95 mins)
# Time 118.13: Patient 29 arrives with triage level 2
# Time 122.57: Patient 30 arrives with triage level 1
# Time 125.07: Patient 25 departs
#   Doctor 2 starts serving Patient 30 (waited 2.50 mins)
# Time 125.90: Patient 30 departs
#   Doctor 2 starts serving Patient 27 (waited 12.90 mins)
# Time 127.72: Patient 26 departs
#   Doctor 0 starts serving Patient 29 (waited 9.59 mins)
# Time 128.08: Patient 27 departs
#   Doctor 2 starts serving Patient 21 (waited 47.59 mins)
# Time 132.56: Patient 22 departs
#   Doctor 1 starts serving Patient 28 (waited 16.90 mins)
# Time 132.80: Patient 28 departs
# Time 134.69: Patient 31 arrives with triage level 2
#   Doctor 1 starts serving Patient 31 (waited 0.00 mins)
# Time 135.14: Patient 21 departs
# Time 135.60: Patient 29 departs
# Time 140.42: Patient 31 departs
# Time 140.94: Patient 32 arrives with triage level 2
#   Doctor 0 starts serving Patient 32 (waited 0.00 mins)
# Time 143.89: Patient 32 departs
# Time 144.01: Patient 33 arrives with triage level 2
#   Doctor 0 starts serving Patient 33 (waited 0.00 mins)
# Time 145.42: Patient 33 departs
# Time 146.55: Patient 34 arrives with triage level 3
#   Doctor 0 starts serving Patient 34 (waited 0.00 mins)
# Time 150.00: Patient 35 arrives with triage level 3
#   Doctor 1 starts serving Patient 35 (waited 0.00 mins)
# Time 152.39: Patient 34 departs
# Time 152.57: Patient 36 arrives with triage level 2
#   Doctor 0 starts serving Patient 36 (waited 0.00 mins)
# Time 155.38: Patient 36 departs
# Time 156.86: Patient 37 arrives with triage level 3
#   Doctor 0 starts serving Patient 37 (waited 0.00 mins)
# Time 157.73: Patient 37 departs
# Time 161.04: Patient 35 departs
# Time 162.28: Patient 38 arrives with triage level 2
#   Doctor 0 starts serving Patient 38 (waited 0.00 mins)
# Time 162.97: Patient 39 arrives with triage level 3
#   Doctor 1 starts serving Patient 39 (waited 0.00 mins)
# Time 165.04: Patient 40 arrives with triage level 3
#   Doctor 2 starts serving Patient 40 (waited 0.00 mins)
# Time 167.35: Patient 41 arrives with triage level 2
# Time 169.16: Patient 42 arrives with triage level 1
# Time 169.73: Patient 43 arrives with triage level 2
# Time 170.48: Patient 38 departs
#   Doctor 0 starts serving Patient 42 (waited 1.32 mins)
# Time 171.31: Patient 39 departs
#   Doctor 1 starts serving Patient 41 (waited 3.96 mins)
# Time 173.71: Patient 40 departs
#   Doctor 2 starts serving Patient 43 (waited 3.98 mins)
# Time 173.79: Patient 44 arrives with triage level 2
# Time 174.70: Patient 45 arrives with triage level 2
# Time 176.35: Patient 42 departs
#   Doctor 0 starts serving Patient 44 (waited 2.56 mins)
# Time 178.76: Patient 43 departs
#   Doctor 2 starts serving Patient 45 (waited 4.05 mins)
# Time 179.70: Patient 44 departs
# Time 179.98: Patient 45 departs
# Time 180.53: Patient 46 arrives with triage level 2
#   Doctor 0 starts serving Patient 46 (waited 0.00 mins)
# Time 181.38: Patient 47 arrives with triage level 3
#   Doctor 2 starts serving Patient 47 (waited 0.00 mins)
# Time 181.67: Patient 47 departs
# Time 184.12: Patient 48 arrives with triage level 3
#   Doctor 2 starts serving Patient 48 (waited 0.00 mins)
# Time 185.82: Patient 48 departs
# Time 187.07: Patient 41 departs
# Time 190.25: Patient 46 departs
# Time 194.55: Patient 49 arrives with triage level 3
#   Doctor 0 starts serving Patient 49 (waited 0.00 mins)
# Time 194.67: Patient 50 arrives with triage level 2
#   Doctor 1 starts serving Patient 50 (waited 0.00 mins)
# Time 195.54: Patient 51 arrives with triage level 2
#   Doctor 2 starts serving Patient 51 (waited 0.00 mins)
# Time 197.96: Patient 49 departs
# Time 199.22: Patient 51 departs
# Time 204.61: Patient 52 arrives with triage level 2
#   Doctor 0 starts serving Patient 52 (waited 0.00 mins)
# Time 208.01: Patient 50 departs
# Time 210.43: Patient 53 arrives with triage level 1
#   Doctor 1 starts serving Patient 53 (waited 0.00 mins)
# Time 211.20: Patient 53 departs
# Time 211.74: Patient 54 arrives with triage level 3
#   Doctor 1 starts serving Patient 54 (waited 0.00 mins)
# Time 211.88: Patient 55 arrives with triage level 2
#   Doctor 2 starts serving Patient 55 (waited 0.00 mins)
# Time 213.36: Patient 56 arrives with triage level 3
# Time 213.65: Patient 57 arrives with triage level 2
# Time 214.12: Patient 58 arrives with triage level 2
# Time 217.17: Patient 54 departs
#   Doctor 1 starts serving Patient 57 (waited 3.53 mins)
# Time 224.44: Patient 59 arrives with triage level 2
# Time 225.65: Patient 60 arrives with triage level 3
# Time 228.14: Patient 61 arrives with triage level 3
# Time 229.67: Patient 57 departs
#   Doctor 1 starts serving Patient 58 (waited 15.55 mins)
# Time 231.68: Patient 52 departs
#   Doctor 0 starts serving Patient 59 (waited 7.25 mins)
# Time 232.25: Patient 59 departs
#   Doctor 0 starts serving Patient 56 (waited 18.88 mins)
# Time 233.40: Patient 56 departs
#   Doctor 0 starts serving Patient 60 (waited 7.75 mins)
# Time 233.40: Patient 62 arrives with triage level 2
# Time 235.25: Patient 63 arrives with triage level 3
# Time 235.37: Patient 64 arrives with triage level 2
# Time 238.02: Patient 55 departs
#   Doctor 2 starts serving Patient 62 (waited 4.62 mins)
# Time 239.95: Patient 65 arrives with triage level 1
# Time 240.59: Patient 62 departs
#   Doctor 2 starts serving Patient 65 (waited 0.64 mins)
# Time 243.23: Patient 66 arrives with triage level 2
# Time 244.27: Patient 60 departs
#   Doctor 0 starts serving Patient 64 (waited 8.90 mins)
# Time 251.25: Patient 64 departs
#   Doctor 0 starts serving Patient 66 (waited 8.02 mins)
# Time 259.32: Patient 58 departs
#   Doctor 1 starts serving Patient 61 (waited 31.17 mins)
# Time 261.35: Patient 67 arrives with triage level 3
# Time 261.47: Patient 61 departs
#   Doctor 1 starts serving Patient 63 (waited 26.22 mins)
# Time 263.63: Patient 63 departs
#   Doctor 1 starts serving Patient 67 (waited 2.28 mins)
# Time 264.44: Patient 66 departs
# Time 265.35: Patient 65 departs
# Time 265.85: Patient 68 arrives with triage level 2
#   Doctor 0 starts serving Patient 68 (waited 0.00 mins)
# Time 266.86: Patient 67 departs
# Time 267.77: Patient 68 departs
# Time 275.72: Patient 69 arrives with triage level 1
#   Doctor 0 starts serving Patient 69 (waited 0.00 mins)
# Time 276.05: Patient 70 arrives with triage level 3
#   Doctor 1 starts serving Patient 70 (waited 0.00 mins)
# Time 277.47: Patient 70 departs
# Time 278.86: Patient 71 arrives with triage level 3
#   Doctor 1 starts serving Patient 71 (waited 0.00 mins)
# Time 283.11: Patient 71 departs
# Time 285.86: Patient 72 arrives with triage level 3
#   Doctor 1 starts serving Patient 72 (waited 0.00 mins)
# Time 286.53: Patient 73 arrives with triage level 1
#   Doctor 2 starts serving Patient 73 (waited 0.00 mins)
# Time 288.13: Patient 74 arrives with triage level 1
# Time 289.67: Patient 69 departs
#   Doctor 0 starts serving Patient 74 (waited 1.54 mins)
# Time 290.23: Patient 72 departs
# Time 293.70: Patient 73 departs
# Time 295.68: Patient 75 arrives with triage level 1
#   Doctor 1 starts serving Patient 75 (waited 0.00 mins)
# Time 299.51: Patient 75 departs
# Time 301.85: Patient 76 arrives with triage level 1
#   Doctor 1 starts serving Patient 76 (waited 0.00 mins)
# Time 306.64: Patient 77 arrives with triage level 3
#   Doctor 2 starts serving Patient 77 (waited 0.00 mins)
# Time 308.73: Patient 77 departs
# Time 312.29: Patient 78 arrives with triage level 3
#   Doctor 2 starts serving Patient 78 (waited 0.00 mins)
# Time 312.70: Patient 76 departs
# Time 314.18: Patient 79 arrives with triage level 3
#   Doctor 1 starts serving Patient 79 (waited 0.00 mins)
# Time 320.04: Patient 80 arrives with triage level 1
# Time 320.13: Patient 79 departs
#   Doctor 1 starts serving Patient 80 (waited 0.09 mins)
# Time 322.36: Patient 80 departs
# Time 329.16: Patient 81 arrives with triage level 2
#   Doctor 1 starts serving Patient 81 (waited 0.00 mins)
# Time 329.44: Patient 78 departs
# Time 338.03: Patient 82 arrives with triage level 2
#   Doctor 2 starts serving Patient 82 (waited 0.00 mins)
# Time 338.41: Patient 83 arrives with triage level 2
# Time 338.62: Patient 84 arrives with triage level 2
# Time 339.07: Patient 81 departs
#   Doctor 1 starts serving Patient 83 (waited 0.67 mins)
# Time 340.53: Patient 83 departs
#   Doctor 1 starts serving Patient 84 (waited 1.92 mins)
# Time 342.68: Patient 85 arrives with triage level 2
# Time 348.95: Patient 82 departs
#   Doctor 2 starts serving Patient 85 (waited 6.27 mins)
# Time 348.99: Patient 85 departs
# Time 356.83: Patient 84 departs
# Time 363.49: Patient 74 departs
# Time 366.84: Patient 86 arrives with triage level 3
#   Doctor 0 starts serving Patient 86 (waited 0.00 mins)
# Time 370.80: Patient 86 departs
# Time 371.62: Patient 87 arrives with triage level 2
#   Doctor 0 starts serving Patient 87 (waited 0.00 mins)
# Time 373.17: Patient 88 arrives with triage level 3
#   Doctor 1 starts serving Patient 88 (waited 0.00 mins)
# Time 373.42: Patient 89 arrives with triage level 2
#   Doctor 2 starts serving Patient 89 (waited 0.00 mins)
# Time 375.16: Patient 87 departs
# Time 379.00: Patient 90 arrives with triage level 3
#   Doctor 0 starts serving Patient 90 (waited 0.00 mins)
# Time 379.32: Patient 91 arrives with triage level 2
# Time 381.68: Patient 88 departs
#   Doctor 1 starts serving Patient 91 (waited 2.36 mins)
# Time 381.75: Patient 90 departs
# Time 384.20: Patient 89 departs
# Time 389.24: Patient 91 departs
# Time 393.74: Patient 92 arrives with triage level 3
#   Doctor 0 starts serving Patient 92 (waited 0.00 mins)
# Time 394.99: Patient 93 arrives with triage level 2
#   Doctor 1 starts serving Patient 93 (waited 0.00 mins)
# Time 400.32: Patient 92 departs
# Time 401.67: Patient 94 arrives with triage level 3
#   Doctor 0 starts serving Patient 94 (waited 0.00 mins)
# Time 402.44: Patient 93 departs
# Time 402.85: Patient 95 arrives with triage level 2
#   Doctor 1 starts serving Patient 95 (waited 0.00 mins)
# Time 404.38: Patient 94 departs
# Time 421.95: Patient 96 arrives with triage level 1
#   Doctor 0 starts serving Patient 96 (waited 0.00 mins)
# Time 424.59: Patient 97 arrives with triage level 3
#   Doctor 2 starts serving Patient 97 (waited 0.00 mins)
# Time 426.98: Patient 96 departs
# Time 429.29: Patient 97 departs
# Time 429.41: Patient 98 arrives with triage level 2
#   Doctor 0 starts serving Patient 98 (waited 0.00 mins)
# Time 429.44: Patient 95 departs
# Time 429.73: Patient 99 arrives with triage level 2
#   Doctor 1 starts serving Patient 99 (waited 0.00 mins)
# Time 430.86: Patient 98 departs
# Time 435.24: Patient 100 arrives with triage level 1
#   Doctor 0 starts serving Patient 100 (waited 0.00 mins)
# Time 435.78: Patient 101 arrives with triage level 2
#   Doctor 2 starts serving Patient 101 (waited 0.00 mins)
# Time 438.14: Patient 102 arrives with triage level 1
# Time 438.56: Patient 101 departs
#   Doctor 2 starts serving Patient 102 (waited 0.42 mins)
# Time 444.85: Patient 100 departs
# Time 444.96: Patient 99 departs
# Time 445.35: Patient 103 arrives with triage level 1
#   Doctor 0 starts serving Patient 103 (waited 0.00 mins)
# Time 446.58: Patient 103 departs
# Time 448.04: Patient 104 arrives with triage level 2
#   Doctor 0 starts serving Patient 104 (waited 0.00 mins)
# Time 451.35: Patient 105 arrives with triage level 1
#   Doctor 1 starts serving Patient 105 (waited 0.00 mins)
# Time 458.87: Patient 104 departs
# Time 458.90: Patient 106 arrives with triage level 2
#   Doctor 0 starts serving Patient 106 (waited 0.00 mins)
# Time 459.56: Patient 106 departs
# Time 460.72: Patient 107 arrives with triage level 1
#   Doctor 0 starts serving Patient 107 (waited 0.00 mins)
# Time 460.80: Patient 108 arrives with triage level 2
# Time 472.56: Patient 109 arrives with triage level 2
# Time 475.97: Patient 110 arrives with triage level 1
# Time 478.74: Patient 105 departs
#   Doctor 1 starts serving Patient 110 (waited 2.77 mins)
# Time 491.92: Patient 110 departs
#   Doctor 1 starts serving Patient 108 (waited 31.12 mins)
# Time 495.85: Patient 108 departs
#   Doctor 1 starts serving Patient 109 (waited 23.29 mins)
# Time 498.56: Patient 102 departs
# Time 499.09: Patient 109 departs
# Time 501.13: Patient 107 departs
# Time 508.48: Patient 111 arrives with triage level 3
#   Doctor 0 starts serving Patient 111 (waited 0.00 mins)
# Time 510.19: Patient 112 arrives with triage level 2
#   Doctor 1 starts serving Patient 112 (waited 0.00 mins)
# Time 512.74: Patient 111 departs
# Time 523.34: Patient 113 arrives with triage level 3
#   Doctor 0 starts serving Patient 113 (waited 0.00 mins)
# Time 530.36: Patient 112 departs
# Time 534.49: Patient 113 departs
# Time 536.72: Patient 114 arrives with triage level 3
#   Doctor 0 starts serving Patient 114 (waited 0.00 mins)
# Time 540.53: Patient 115 arrives with triage level 2
#   Doctor 1 starts serving Patient 115 (waited 0.00 mins)
# Time 545.25: Patient 116 arrives with triage level 2
#   Doctor 2 starts serving Patient 116 (waited 0.00 mins)
# Time 546.49: Patient 115 departs
# Time 549.14: Patient 116 departs
# Time 549.76: Patient 114 departs
# Time 554.13: Patient 117 arrives with triage level 2
#   Doctor 0 starts serving Patient 117 (waited 0.00 mins)
# Time 560.47: Patient 117 departs
# Time 563.60: Patient 118 arrives with triage level 3
#   Doctor 0 starts serving Patient 118 (waited 0.00 mins)
# Time 564.95: Patient 118 departs
# Time 566.30: Patient 119 arrives with triage level 1
#   Doctor 0 starts serving Patient 119 (waited 0.00 mins)
# Time 566.55: Patient 120 arrives with triage level 1
#   Doctor 1 starts serving Patient 120 (waited 0.00 mins)
# Time 572.23: Patient 121 arrives with triage level 2
#   Doctor 2 starts serving Patient 121 (waited 0.00 mins)
# Time 572.44: Patient 120 departs
# Time 573.09: Patient 119 departs
# Time 580.19: Patient 122 arrives with triage level 2
#   Doctor 0 starts serving Patient 122 (waited 0.00 mins)
# Time 583.01: Patient 121 departs
# Time 587.62: Patient 123 arrives with triage level 2
#   Doctor 1 starts serving Patient 123 (waited 0.00 mins)
# Time 587.67: Patient 122 departs
# Time 590.32: Patient 123 departs
# Time 593.21: Patient 124 arrives with triage level 2
#   Doctor 0 starts serving Patient 124 (waited 0.00 mins)
# Time 596.58: Patient 125 arrives with triage level 1
#   Doctor 1 starts serving Patient 125 (waited 0.00 mins)
# Time 596.83: Patient 126 arrives with triage level 2
#   Doctor 2 starts serving Patient 126 (waited 0.00 mins)
# Time 607.82: Patient 126 departs
# Time 608.58: Patient 127 arrives with triage level 3
#   Doctor 2 starts serving Patient 127 (waited 0.00 mins)
# Time 608.71: Patient 128 arrives with triage level 2
# Time 609.08: Patient 129 arrives with triage level 3
# Time 609.14: Patient 124 departs
#   Doctor 0 starts serving Patient 128 (waited 0.42 mins)
# Time 610.55: Patient 130 arrives with triage level 2
# Time 613.34: Patient 125 departs
#   Doctor 1 starts serving Patient 130 (waited 2.78 mins)
# Time 614.89: Patient 130 departs
#   Doctor 1 starts serving Patient 129 (waited 5.81 mins)
# Time 617.08: Patient 128 departs
# Time 623.73: Patient 131 arrives with triage level 2
#   Doctor 0 starts serving Patient 131 (waited 0.00 mins)
# Time 625.21: Patient 129 departs
# Time 630.14: Patient 132 arrives with triage level 3
#   Doctor 1 starts serving Patient 132 (waited 0.00 mins)
# Time 633.81: Patient 127 departs
# Time 634.09: Patient 132 departs
# Time 634.10: Patient 133 arrives with triage level 1
#   Doctor 1 starts serving Patient 133 (waited 0.00 mins)
# Time 637.35: Patient 134 arrives with triage level 3
#   Doctor 2 starts serving Patient 134 (waited 0.00 mins)
# Time 638.00: Patient 134 departs
# Time 638.48: Patient 133 departs
# Time 639.01: Patient 135 arrives with triage level 1
#   Doctor 1 starts serving Patient 135 (waited 0.00 mins)
# Time 644.22: Patient 131 departs
# Time 644.83: Patient 136 arrives with triage level 3
#   Doctor 0 starts serving Patient 136 (waited 0.00 mins)
# Time 647.99: Patient 137 arrives with triage level 2
#   Doctor 2 starts serving Patient 137 (waited 0.00 mins)
# Time 650.38: Patient 136 departs
# Time 651.06: Patient 138 arrives with triage level 2
#   Doctor 0 starts serving Patient 138 (waited 0.00 mins)
# Time 657.27: Patient 138 departs
# Time 666.04: Patient 137 departs
# Time 668.38: Patient 139 arrives with triage level 2
#   Doctor 0 starts serving Patient 139 (waited 0.00 mins)
# Time 668.54: Patient 140 arrives with triage level 3
#   Doctor 2 starts serving Patient 140 (waited 0.00 mins)
# Time 669.99: Patient 139 departs
# Time 673.58: Patient 141 arrives with triage level 1
#   Doctor 0 starts serving Patient 141 (waited 0.00 mins)
# Time 674.06: Patient 141 departs
# Time 674.37: Patient 142 arrives with triage level 3
#   Doctor 0 starts serving Patient 142 (waited 0.00 mins)
# Time 678.58: Patient 143 arrives with triage level 2
# Time 678.81: Patient 140 departs
#   Doctor 2 starts serving Patient 143 (waited 0.23 mins)
# Time 680.31: Patient 144 arrives with triage level 2
# Time 681.66: Patient 135 departs
#   Doctor 1 starts serving Patient 144 (waited 1.36 mins)
# Time 682.07: Patient 144 departs
# Time 682.20: Patient 142 departs
# Time 683.76: Patient 145 arrives with triage level 2
#   Doctor 0 starts serving Patient 145 (waited 0.00 mins)
# Time 687.77: Patient 146 arrives with triage level 3
#   Doctor 1 starts serving Patient 146 (waited 0.00 mins)
# Time 688.01: Patient 146 departs
# Time 691.96: Patient 147 arrives with triage level 2
#   Doctor 1 starts serving Patient 147 (waited 0.00 mins)
# Time 696.69: Patient 145 departs
# Time 698.86: Patient 147 departs
# Time 700.76: Patient 148 arrives with triage level 1
#   Doctor 0 starts serving Patient 148 (waited 0.00 mins)
# Time 701.48: Patient 149 arrives with triage level 1
#   Doctor 1 starts serving Patient 149 (waited 0.00 mins)
# Time 708.05: Patient 143 departs
# Time 711.09: Patient 149 departs
# Time 712.15: Patient 150 arrives with triage level 2
#   Doctor 1 starts serving Patient 150 (waited 0.00 mins)
# Time 714.95: Patient 150 departs
# Time 717.34: Patient 151 arrives with triage level 2
#   Doctor 1 starts serving Patient 151 (waited 0.00 mins)
# Time 718.59: Patient 148 departs
# Time 719.62: Patient 152 arrives with triage level 2
#   Doctor 0 starts serving Patient 152 (waited 0.00 mins)
# Time 719.94: Patient 151 departs
# Time 725.29: Patient 153 arrives with triage level 2
#   Doctor 1 starts serving Patient 153 (waited 0.00 mins)
# Time 730.51: Patient 154 arrives with triage level 2
#   Doctor 2 starts serving Patient 154 (waited 0.00 mins)
# Time 731.01: Patient 155 arrives with triage level 3
# Time 731.54: Patient 152 departs
#   Doctor 0 starts serving Patient 155 (waited 0.53 mins)
# Time 732.57: Patient 154 departs
# Time 733.77: Patient 156 arrives with triage level 3
#   Doctor 2 starts serving Patient 156 (waited 0.00 mins)
# Time 734.71: Patient 155 departs
# Time 735.85: Patient 156 departs
# Time 736.82: Patient 153 departs
# Time 740.55: Patient 157 arrives with triage level 3
#   Doctor 0 starts serving Patient 157 (waited 0.00 mins)
# Time 743.31: Patient 158 arrives with triage level 3
#   Doctor 1 starts serving Patient 158 (waited 0.00 mins)
# Time 746.05: Patient 158 departs
# Time 746.41: Patient 157 departs
# Time 753.35: Patient 159 arrives with triage level 2
#   Doctor 0 starts serving Patient 159 (waited 0.00 mins)
# Time 756.86: Patient 160 arrives with triage level 2
#   Doctor 1 starts serving Patient 160 (waited 0.00 mins)
# Time 757.69: Patient 160 departs
# Time 758.37: Patient 161 arrives with triage level 1
#   Doctor 1 starts serving Patient 161 (waited 0.00 mins)
# Time 775.65: Patient 162 arrives with triage level 1
#   Doctor 2 starts serving Patient 162 (waited 0.00 mins)
# Time 781.10: Patient 163 arrives with triage level 1
# Time 781.66: Patient 159 departs
#   Doctor 0 starts serving Patient 163 (waited 0.57 mins)
# Time 782.22: Patient 164 arrives with triage level 1
# Time 784.65: Patient 161 departs
#   Doctor 1 starts serving Patient 164 (waited 2.42 mins)
# Time 784.71: Patient 162 departs
# Time 786.60: Patient 165 arrives with triage level 2
#   Doctor 2 starts serving Patient 165 (waited 0.00 mins)
# Time 787.19: Patient 165 departs
# Time 790.41: Patient 166 arrives with triage level 2
#   Doctor 2 starts serving Patient 166 (waited 0.00 mins)
# Time 796.80: Patient 163 departs
# Time 801.46: Patient 164 departs
# Time 806.68: Patient 167 arrives with triage level 1
#   Doctor 0 starts serving Patient 167 (waited 0.00 mins)
# Time 823.60: Patient 167 departs
# Time 824.34: Patient 168 arrives with triage level 3
#   Doctor 0 starts serving Patient 168 (waited 0.00 mins)
# Time 825.06: Patient 168 departs
# Time 825.43: Patient 169 arrives with triage level 2
#   Doctor 0 starts serving Patient 169 (waited 0.00 mins)
# Time 827.56: Patient 169 departs
# Time 827.61: Patient 170 arrives with triage level 2
#   Doctor 0 starts serving Patient 170 (waited 0.00 mins)
# Time 831.62: Patient 170 departs
# Time 834.23: Patient 171 arrives with triage level 2
#   Doctor 0 starts serving Patient 171 (waited 0.00 mins)
# Time 834.71: Patient 172 arrives with triage level 2
#   Doctor 1 starts serving Patient 172 (waited 0.00 mins)
# Time 834.91: Patient 173 arrives with triage level 3
# Time 838.15: Patient 174 arrives with triage level 2
# Time 842.11: Patient 172 departs
#   Doctor 1 starts serving Patient 174 (waited 3.96 mins)
# Time 845.21: Patient 166 departs
#   Doctor 2 starts serving Patient 173 (waited 10.30 mins)
# Time 845.82: Patient 175 arrives with triage level 1
# Time 848.78: Patient 176 arrives with triage level 2
# Time 848.98: Patient 174 departs
#   Doctor 1 starts serving Patient 175 (waited 3.16 mins)
# Time 850.77: Patient 171 departs
#   Doctor 0 starts serving Patient 176 (waited 1.99 mins)
# Time 851.76: Patient 173 departs
# Time 857.95: Patient 176 departs
# Time 858.06: Patient 177 arrives with triage level 3
#   Doctor 0 starts serving Patient 177 (waited 0.00 mins)
# Time 860.54: Patient 177 departs
# Time 860.85: Patient 178 arrives with triage level 2
#   Doctor 0 starts serving Patient 178 (waited 0.00 mins)
# Time 861.21: Patient 175 departs
# Time 861.89: Patient 178 departs
# Time 862.07: Patient 179 arrives with triage level 2
#   Doctor 0 starts serving Patient 179 (waited 0.00 mins)
# Time 866.88: Patient 180 arrives with triage level 1
#   Doctor 1 starts serving Patient 180 (waited 0.00 mins)
# Time 867.50: Patient 181 arrives with triage level 3
#   Doctor 2 starts serving Patient 181 (waited 0.00 mins)
# Time 876.08: Patient 181 departs
# Time 877.26: Patient 182 arrives with triage level 1
#   Doctor 2 starts serving Patient 182 (waited 0.00 mins)
# Time 880.92: Patient 182 departs
# Time 881.48: Patient 179 departs
# Time 882.77: Patient 180 departs
# Time 884.14: Patient 183 arrives with triage level 2
#   Doctor 0 starts serving Patient 183 (waited 0.00 mins)
# Time 889.38: Patient 184 arrives with triage level 3
#   Doctor 1 starts serving Patient 184 (waited 0.00 mins)
# Time 896.01: Patient 183 departs
# Time 903.08: Patient 185 arrives with triage level 3
#   Doctor 0 starts serving Patient 185 (waited 0.00 mins)
# Time 903.65: Patient 185 departs
# Time 906.81: Patient 186 arrives with triage level 2
#   Doctor 0 starts serving Patient 186 (waited 0.00 mins)
# Time 910.87: Patient 184 departs
# Time 915.68: Patient 187 arrives with triage level 3
#   Doctor 1 starts serving Patient 187 (waited 0.00 mins)
# Time 917.39: Patient 186 departs
# Time 919.48: Patient 187 departs
# Time 919.77: Patient 188 arrives with triage level 2
#   Doctor 0 starts serving Patient 188 (waited 0.00 mins)
# Time 920.70: Patient 189 arrives with triage level 3
#   Doctor 1 starts serving Patient 189 (waited 0.00 mins)
# Time 921.62: Patient 190 arrives with triage level 3
#   Doctor 2 starts serving Patient 190 (waited 0.00 mins)
# Time 921.94: Patient 188 departs
# Time 923.18: Patient 191 arrives with triage level 2
#   Doctor 0 starts serving Patient 191 (waited 0.00 mins)
# Time 925.33: Patient 190 departs
# Time 927.03: Patient 192 arrives with triage level 2
#   Doctor 2 starts serving Patient 192 (waited 0.00 mins)
# Time 927.75: Patient 189 departs
# Time 928.02: Patient 193 arrives with triage level 1
#   Doctor 1 starts serving Patient 193 (waited 0.00 mins)
# Time 929.24: Patient 194 arrives with triage level 2
# Time 930.42: Patient 195 arrives with triage level 2
# Time 932.18: Patient 191 departs
#   Doctor 0 starts serving Patient 194 (waited 2.94 mins)
# Time 933.59: Patient 194 departs
#   Doctor 0 starts serving Patient 195 (waited 3.17 mins)
# Time 934.07: Patient 196 arrives with triage level 2
# Time 936.23: Patient 192 departs
#   Doctor 2 starts serving Patient 196 (waited 2.16 mins)
# Time 936.47: Patient 195 departs
# Time 937.13: Patient 193 departs
# Time 942.99: Patient 197 arrives with triage level 2
#   Doctor 0 starts serving Patient 197 (waited 0.00 mins)
# Time 946.63: Patient 196 departs
# Time 946.83: Patient 198 arrives with triage level 2
#   Doctor 1 starts serving Patient 198 (waited 0.00 mins)
# Time 947.21: Patient 199 arrives with triage level 1
#   Doctor 2 starts serving Patient 199 (waited 0.00 mins)
# Time 948.57: Patient 197 departs
# Time 954.98: Patient 200 arrives with triage level 3
#   Doctor 0 starts serving Patient 200 (waited 0.00 mins)
# Time 955.77: Patient 200 departs
# Time 960.28: Patient 198 departs
# Time 961.18: Patient 201 arrives with triage level 2
#   Doctor 0 starts serving Patient 201 (waited 0.00 mins)
# Time 963.76: Patient 202 arrives with triage level 3
#   Doctor 1 starts serving Patient 202 (waited 0.00 mins)
# Time 964.05: Patient 199 departs
# Time 965.03: Patient 203 arrives with triage level 3
#   Doctor 2 starts serving Patient 203 (waited 0.00 mins)
# Time 965.07: Patient 203 departs
# Time 967.54: Patient 204 arrives with triage level 3
#   Doctor 2 starts serving Patient 204 (waited 0.00 mins)
# Time 972.44: Patient 202 departs
# Time 977.06: Patient 204 departs
# Time 977.74: Patient 205 arrives with triage level 2
#   Doctor 1 starts serving Patient 205 (waited 0.00 mins)
# Time 978.69: Patient 206 arrives with triage level 2
#   Doctor 2 starts serving Patient 206 (waited 0.00 mins)
# Time 980.14: Patient 207 arrives with triage level 2
# Time 981.93: Patient 201 departs
#   Doctor 0 starts serving Patient 207 (waited 1.79 mins)
# Time 982.23: Patient 206 departs
# Time 985.91: Patient 208 arrives with triage level 2
#   Doctor 2 starts serving Patient 208 (waited 0.00 mins)
# Time 986.68: Patient 208 departs
# Time 988.55: Patient 207 departs
# Time 989.67: Patient 205 departs
# Time 990.37: Patient 209 arrives with triage level 1
#   Doctor 0 starts serving Patient 209 (waited 0.00 mins)
# Time 995.66: Patient 209 departs
# Time 998.87: Patient 210 arrives with triage level 1
#   Doctor 0 starts serving Patient 210 (waited 0.00 mins)
# Time 1012.44: Patient 210 departs
#
# Simulation Complete.
#
# Total patients served: 211
# Average wait time: 1.89 minutes
# Doctor 0 utilization: 75.93%
# Doctor 1 utilization: 69.36%
# Doctor 2 utilization: 51.88%
